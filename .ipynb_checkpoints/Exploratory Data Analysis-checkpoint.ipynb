# %%
import pandas as pd

# %%
data=pd.read_csv("updated_dataset.csv")
data
# Out:
#                                                   title  rating  \
# 0                   Unreliable earphones with high cost     1.0
# 1                   Honest review of an edm music lover     3.0
# 2                              Really good and durable.     4.0
# 3     A good earphone but with some issues, read thi...     4.0
# 4                             Charging port not working     1.0
# ...                                                 ...     ...
# 4995                                 Rate are upto mark     4.0
# 4996  Only working in 2 Months No service centre in ...     2.0
# 4997  Thumbs up for sound , double thumbs down for b...     2.0
# 4998                       Very poor noise cancellation     1.0
# 4999                    Worst BT device for smart phone     1.0
#
#                                                    body  y  \
# 0     this  earphones are unreliable i bought it bef...  0
# 1     no doubt it has a great bass and to a great ex...  1
# 2     i bought itfor 999i purchased it second time g...  2
# 3     ill get straight to the pros and cons of boat ...  2
# 4     after 11 days the charging port isnt working a...  0
# ...                                                 ... ..
# 4995  little rusty packing but product is good this ...  2
# 4996  last july 7 i purchased boat 255 bluetooth hea...  0
# 4997  i reduced two stars from my average because of...  0
# 4998  the major drawback is no noise cancellation at...  0
# 4999  i bought this device 5 months ago now the bt p...  0
#
#                                         cleaned_reviews
# 0     earphon unreli bought day meanwhil right side ...
# 1     doubt great bass great extent nois cancel dece...
# 2     bought itfor purchas second time gift first on...
# 3     ill get straight pro con boat rockerz pro blue...
# 4     day charg port isnt work cant even return wat ...
# ...                                                 ...
# 4995  littl rusti pack product good first purchas bo...
# 4996  last juli purchas boat bluetooth headset rd st...
# 4997  reduc two star averag batteri life last hour w...
# 4998  major drawback nois cancel opposit person alwa...
# 4999  bought devic month ago bt pair work properli t...
#
# [5000 rows x 5 columns]

# %%
# Changes the overall category to categorical from numerical for easier visualizations
data["classes"] = data["rating"]
data["classes"].replace({5.0: "positive",4.0:"positive",3.0:"neutral",2.0:"negative",1.0:"negative"}, inplace=True)
data["classes"].unique()
# Out:
# array(['negative', 'neutral', 'positive'], dtype=object)

# %%
data['classes'].value_counts()
# Out:
# positive    2405
# negative    1786
# neutral      809
# Name: classes, dtype: int64

# %%
data
# Out:
#                                                   title  rating  \
# 0                   Unreliable earphones with high cost     1.0
# 1                   Honest review of an edm music lover     3.0
# 2                              Really good and durable.     4.0
# 3     A good earphone but with some issues, read thi...     4.0
# 4                             Charging port not working     1.0
# ...                                                 ...     ...
# 4995                                 Rate are upto mark     4.0
# 4996  Only working in 2 Months No service centre in ...     2.0
# 4997  Thumbs up for sound , double thumbs down for b...     2.0
# 4998                       Very poor noise cancellation     1.0
# 4999                    Worst BT device for smart phone     1.0
#
#                                                    body  y  \
# 0     this  earphones are unreliable i bought it bef...  0
# 1     no doubt it has a great bass and to a great ex...  1
# 2     i bought itfor 999i purchased it second time g...  2
# 3     ill get straight to the pros and cons of boat ...  2
# 4     after 11 days the charging port isnt working a...  0
# ...                                                 ... ..
# 4995  little rusty packing but product is good this ...  2
# 4996  last july 7 i purchased boat 255 bluetooth hea...  0
# 4997  i reduced two stars from my average because of...  0
# 4998  the major drawback is no noise cancellation at...  0
# 4999  i bought this device 5 months ago now the bt p...  0
#
#                                         cleaned_reviews   classes
# 0     earphon unreli bought day meanwhil right side ...  negative
# 1     doubt great bass great extent nois cancel dece...   neutral
# 2     bought itfor purchas second time gift first on...  positive
# 3     ill get straight pro con boat rockerz pro blue...  positive
# 4     day charg port isnt work cant even return wat ...  negative
# ...                                                 ...       ...
# 4995  littl rusti pack product good first purchas bo...  positive
# 4996  last juli purchas boat bluetooth headset rd st...  negative
# 4997  reduc two star averag batteri life last hour w...  negative
# 4998  major drawback nois cancel opposit person alwa...  negative
# 4999  bought devic month ago bt pair work properli t...  negative
#
# [5000 rows x 6 columns]

# %%
data.isna().sum()
# Out:
# title              1
# rating             0
# body               0
# y                  0
# cleaned_reviews    3
# classes            0
# dtype: int64

# %%
data=data.dropna()

# %%
data.isna().sum()
# Out:
# title              0
# rating             0
# body               0
# y                  0
# cleaned_reviews    0
# classes            0
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Distribution of sentiment class
fig, axes = plt.subplots(1, figsize=(15,8))
fig.suptitle("Comparing Ratio of Neutral Negative and Positive ratings", fontsize = 25)
plt.tight_layout(pad = 3.5)
sns.countplot(x = "classes", data = data)
axes.set_xlabel("Sentiment", fontsize = 20)
axes.set_ylabel("Count", fontsize = 20)
sns.despine()

# %%
def pert_count(data, category):
    return (len(data[data["classes"] == category])/len(data)) * 100

# %%
print(f"Percentage of neutral words  {pert_count(data, 'neutral')} %")
print(f"Percentage of negative words  {pert_count(data, 'negative')} %")
print(f"Percentage of positive words  {pert_count(data, 'positive')} %")
# Out:
# Percentage of neutral words  16.172938350680543 %
# Percentage of negative words  35.748598879103284 %
# Percentage of positive words  48.07846277021618 %

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\vinis\anaconda3\lib\site-packages (1.8.1)
# Requirement already satisfied: matplotlib in c:\users\vinis\anaconda3\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: pillow in c:\users\vinis\anaconda3\lib\site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\vinis\anaconda3\lib\site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vinis\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vinis\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vinis\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vinis\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: six in c:\users\vinis\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)
def word_cloud(data, title):
    wordcloud = WordCloud(
    background_color = "black",
    max_font_size = 40,
    max_words = 200,
    stopwords = stopwords,
    scale = 3).generate(str(data))
    fig = plt.figure(figsize = (7.5, 7.5))
    plt.axis("off")
    if title: 
        fig.suptitle(title, fontsize=15)
        fig.subplots_adjust(top=2.25)
    plt.imshow(wordcloud)
    plt.show()

# %%
# seperating all records into a different variable to generate wordcloud based on category
neu=data[data["classes"] == "neutral"]["cleaned_reviews"]
neg=data[data["classes"] == "negative"]["cleaned_reviews"]
pos=data[data["classes"] == "positive"]["cleaned_reviews"]

# %%
# Generating wordcloud based on category
word_cloud(neu, "Most Repeated words in neutral reviews")
word_cloud(pos, "Most Repeated words in positive reviews")
word_cloud(neg, "Most Repeated words in negative reviews")

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer,TfidfVectorizer

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2),stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
# create a function for bigram plots
def n_gram_plot(data,title,color):
    x=[x[0] for x in data]
    y=[x[1] for x in data]
    sns.barplot(y,x,color='{}'.format(color))
    plt.title('{} Reviews Bigrams'.format(title),fontsize=15)
    plt.yticks(rotation=0,fontsize=15)

common_words_good = get_top_n_bigram(pos, 5)
common_words_neutral= get_top_n_bigram(neu, 5)
common_words_bad= get_top_n_bigram(neg, 5)

# bigram plot using function above
plt.figure(figsize=(10,5))
# good reviews bigrams
plt.subplot(151)
n_gram_plot(common_words_good,'Good','green')

#neutral reviews bigrams
plt.subplot(153)
n_gram_plot(common_words_neutral,'Neutral','yellow')

#bad reviews bigrams
plt.subplot(155)
n_gram_plot(common_words_bad,'Bad','red')
plt.show()
# Out:
# C:\Users\vinis\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vinis\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vinis\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\vinis\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\vinis\anaconda3\lib\site-packages (from textblob) (3.6.5)
# Requirement already satisfied: click in c:\users\vinis\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: joblib in c:\users\vinis\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\vinis\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\vinis\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: colorama in c:\users\vinis\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ###### Calculating sentiment polarity

# %%
from textblob import TextBlob
data['sentiment'] = data['cleaned_reviews'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)
data.head()
# Out:
# C:\Users\vinis\AppData\Local\Temp/ipykernel_6848/1649587928.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sentiment'] = data['cleaned_reviews'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)
#                                                title  rating  \
# 0                Unreliable earphones with high cost     1.0
# 1                Honest review of an edm music lover     3.0
# 2                           Really good and durable.     4.0
# 3  A good earphone but with some issues, read thi...     4.0
# 4                          Charging port not working     1.0
#
#                                                 body  y  \
# 0  this  earphones are unreliable i bought it bef...  0
# 1  no doubt it has a great bass and to a great ex...  1
# 2  i bought itfor 999i purchased it second time g...  2
# 3  ill get straight to the pros and cons of boat ...  2
# 4  after 11 days the charging port isnt working a...  0
#
#                                      cleaned_reviews   classes  sentiment
# 0  earphon unreli bought day meanwhil right side ...  negative   0.405952
# 1  doubt great bass great extent nois cancel dece...   neutral   0.067500
# 2  bought itfor purchas second time gift first on...  positive   0.316667
# 3  ill get straight pro con boat rockerz pro blue...  positive   0.104297
# 4  day charg port isnt work cant even return wat ...  negative   0.136364

# %%
data['sentiment'].value_counts()
# Out:
#  0.000000    270
#  0.700000     81
#  0.400000     64
#  0.500000     59
#  0.550000     58
#             ...
# -0.272917      1
# -0.113889      1
#  0.282051      1
#  0.355556      1
#  0.302083      1
# Name: sentiment, Length: 2264, dtype: int64

# %%
data['rating'].value_counts()
# Out:
# 1.0    1289
# 5.0    1239
# 4.0    1163
# 3.0     808
# 2.0     497
# Name: rating, dtype: int64

# %%
944*10
# Out:
# 9440

# %% [markdown]
# ###### visualize the sentiment distribution

# %%
plt.xlabel('Sentiment', fontsize=10)
plt.xticks(fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.yticks(fontsize=10)
plt.margins(0.5)
plt.hist(data['sentiment'], bins=10)
plt.title('Sentiment Distribution', fontsize=10)
plt.show()

# %% [markdown]
# #### We can conclude that there's more reviews that look neutral and negative exist in our dataset than there are positive reviews. We also see that people tend to put in reviews only when its neutral or when its negative and they barely bother to put up a review when its a really good product.

# %%
data['word_count'] = data["title"].apply(lambda x: len(str(x).split(" ")))
data['review_len'] =data["title"].apply(lambda x: len(str(x)))

# visualising the heatmap
correlation = data[['rating','sentiment', 'review_len', 'word_count']].corr()
mask = np.zeros_like(correlation, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(30,10))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
sns.heatmap(correlation, cmap='coolwarm', annot=True, annot_kws={"size": 12}, linewidths=10, vmin=-1.5, mask=mask)
# Out:
# C:\Users\vinis\AppData\Local\Temp/ipykernel_6848/4150715145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['word_count'] = data["title"].apply(lambda x: len(str(x).split(" ")))
# C:\Users\vinis\AppData\Local\Temp/ipykernel_6848/4150715145.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['review_len'] =data["title"].apply(lambda x: len(str(x)))
# C:\Users\vinis\AppData\Local\Temp/ipykernel_6848/4150715145.py:6: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(correlation, dtype=np.bool)
# <AxesSubplot:>

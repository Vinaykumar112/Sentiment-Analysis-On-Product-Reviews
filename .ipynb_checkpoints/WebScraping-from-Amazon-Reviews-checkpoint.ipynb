# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_soup(u):
    r = requests.get(u,headers=HEADERS)
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup
review_list=[]
# soup

# %%
# Function 2: look for web-tags in our soup, then append our data to reviewList
def get_reviews(soup):
    reviews = soup.find_all('div', {'data-hook': 'review'})
    try:
        for item in reviews:
            review = {
            'title': item.find('a', {'class': 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold'}).text.strip(),
            'rating':float(item.find('i', {"data-hook":"review-star-rating"}).text.replace('out of 5 stars', '').strip()),
            'body': item.find('div', {'class': 'a-row a-spacing-small review-data'}).text.strip(),
            }
            review_list.append(review)
    except:
        pass

# %%
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
            AppleWebKit/537.36 (KHTML, like Gecko) \
            Chrome/90.0.4430.212 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
for x in range(0,500):
    soup = get_soup(f'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/product-reviews/B08TSSCZR8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber={x}')
    #print(soup)
    print(f'Getting page: {x}')
    get_reviews(soup)
    print(len(review_list))
    if not soup.find('li', {'class': 'a-disabled a-last'}):
        pass
    else:
        break
# Out:
# Getting page: 0
# 10
# Getting page: 1
# 20
# Getting page: 2
# 30
# Getting page: 3
# 40
# Getting page: 4
# 50
# Getting page: 5
# 60
# Getting page: 6
# 70
# Getting page: 7
# 80
# Getting page: 8
# 90
# Getting page: 9
# 100
# Getting page: 10
# 110
# Getting page: 11
# 120
# Getting page: 12
# 130
# Getting page: 13
# 140
# Getting page: 14
# 150
# Getting page: 15
# 160
# Getting page: 16
# 170
# Getting page: 17
# 180
# Getting page: 18
# 190
# Getting page: 19
# 200
# Getting page: 20
# 210
# Getting page: 21
# 220
# Getting page: 22
# 230
# Getting page: 23
# 240
# Getting page: 24
# 250
# Getting page: 25
# 260
# Getting page: 26
# 270
# Getting page: 27
# 280
# Getting page: 28
# 290
# Getting page: 29
# 300
# Getting page: 30
# 310
# Getting page: 31
# 320
# Getting page: 32
# 330
# Getting page: 33
# 340
# Getting page: 34
# 350
# Getting page: 35
# 360
# Getting page: 36
# 370
# Getting page: 37
# 380
# Getting page: 38
# 390
# Getting page: 39
# 400
# Getting page: 40
# ...

# %%
df2 = pd.DataFrame(review_list)
#df2.to_csv(r'rrrrredmi-10a.csv', index=False)
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2636/30748065.py in <module>
# ----> 1 df2 = pd.DataFrame(review_list)
#       2 #df2.to_csv(r'rrrrredmi-10a.csv', index=False)
#       3 df2
#
# NameError: name 'review_list' is not defined

# %%
df2.shape
# Out:
# (5000, 3)

# %%
df2['title'].nunique()
# Out:
# 4518

# %%
df2['body'].nunique()
# Out:
# 4986

# %%
df2.head(50)
# Out:
#                                                 title  rating  \
# 0                 Unreliable earphones with high cost     1.0
# 1                 Honest review of an edm music lover     3.0
# 2                            Really good and durable.     4.0
# 3   A good earphone but with some issues, read thi...     4.0
# 4                           Charging port not working     1.0
# 5                       धांसू Bass & जबरदस्त Battery.     4.0
# 6      Just Awesome Wireless Headphone under 1000...😉     5.0
# 7                     stopped working in just 14 days     1.0
# 8                         Great sound with worst mic.     3.0
# 9                              Very very bad Durabity     1.0
# 10                Unreliable earphones with high cost     1.0
# 11                Honest review of an edm music lover     3.0
# 12                           Really good and durable.     4.0
# 13  A good earphone but with some issues, read thi...     4.0
# ...

# %%
df2['title'].nunique()
# Out:
# 4518

# %%
df2['title'].value_counts()
# Out:
# Value for money                                                               37
# Good product                                                                  24
# Good                                                                          20
# Disappointed                                                                  16
# Waste of money                                                                16
#                                                                               ..
# Overall average product.                                                       1
# Damm Awesome Earphones                                                         1
# Okay, need to improve..                                                        1
# Give some online help about to replacement/ return/ repair of the product.     1
# Worst BT device for smart phone                                                1
# Name: title, Length: 4518, dtype: int64

# %%
df2.isna().sum()
# Out:
# title     0
# rating    0
# body      0
# dtype: int64

# %%
df2['body'].nunique()
# Out:
# 4986

# %%
df2 = pd.DataFrame(review_list)
df2.to_csv(r'boat-earphone-scrap.csv', index=False)
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2636/881640891.py in <module>
# ----> 1 df2 = pd.DataFrame(review_list)
#       2 df2.to_csv(r'boat-earphone-scrap.csv', index=False)
#       3 df2
#
# NameError: name 'pd' is not defined

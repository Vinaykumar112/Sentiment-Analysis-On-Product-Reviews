# %%
import pandas as pd
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

import nltk
import re
import string
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vinis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
df=pd.read_csv("mobile-samsung.csv")
df
# Out:
#                                              title  rating  \
# 0                                 Horrible product     1.0
# 1                                          Overall     4.0
# 2          Camera quality is not like 48 megapixel     3.0
# 3                                 A big no from me     1.0
# 4                    Put your money somewhere else     1.0
# ...                                            ...     ...
# 4995                     It could have been better     2.0
# 4996  Superb battery life.......👌👌👌👌one ui best👌👌👌     4.0
# 4997                        Do not buy this phone,     3.0
# 4998        Kuch khas nhi phon mai cemara to 0 haj     5.0
# 4999                     Samsung's new budget king     5.0
#
#                                                    body
# 0     Very disappointed with the overall performance...
# 1     Got the mobile on the launch date,Battery must...
# 2                                 Camera quality is low
# 3     1. It doesn't work with 5.0GHz WiFi frequency....
# 4     Not worth buying....faulty software, poor disp...
# ...                                                 ...
# 4995  Too heavy n bulgy in this era. Not good as sec...
# 4996  Nice mobile , battery life is very good and ch...
# 4997  Camera quality is not good, look like 13mega p...
# 4998  Phon mai bettry  fingerprint shi hai bas bki k...
# 4999  This is a budget friendly phone from Samsung.....
#
# [5000 rows x 3 columns]

# %%
df['title'].nunique()
# Out:
# 3982

# %%
df.dtypes
# Out:
# title      object
# rating    float64
# body       object
# dtype: object

# %%
df['body'].nunique()
# Out:
# 4770

# %%
def classify(x):
    if x == 5.0 or x==4.0:
        return 2
    if x==3.0:
        return 1 
    return 0

# %%
def clean_dataframe(df):
  # creates new column with corresponding class labels, the output variable.
  df['y'] = df['rating'].apply(classify)

# %%
clean_dataframe(df)

# %%
df
# Out:
#                                              title  rating  \
# 0                                 Horrible product     1.0
# 1                                          Overall     4.0
# 2          Camera quality is not like 48 megapixel     3.0
# 3                                 A big no from me     1.0
# 4                    Put your money somewhere else     1.0
# ...                                            ...     ...
# 4995                     It could have been better     2.0
# 4996  Superb battery life.......👌👌👌👌one ui best👌👌👌     4.0
# 4997                        Do not buy this phone,     3.0
# 4998        Kuch khas nhi phon mai cemara to 0 haj     5.0
# 4999                     Samsung's new budget king     5.0
#
#                                                    body  y
# 0     Very disappointed with the overall performance...  0
# 1     Got the mobile on the launch date,Battery must...  2
# 2                                 Camera quality is low  1
# 3     1. It doesn't work with 5.0GHz WiFi frequency....  0
# 4     Not worth buying....faulty software, poor disp...  0
# ...                                                 ... ..
# 4995  Too heavy n bulgy in this era. Not good as sec...  0
# 4996  Nice mobile , battery life is very good and ch...  2
# 4997  Camera quality is not good, look like 13mega p...  1
# 4998  Phon mai bettry  fingerprint shi hai bas bki k...  2
# 4999  This is a budget friendly phone from Samsung.....  2
#
# [5000 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# title     0
# rating    0
# body      9
# y         0
# dtype: int64

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (4991, 4)

# %%
# removes all the punctuations ie '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
import string
def remove_punctuation(text):
    no_punct=[words for words in text if words not in string.punctuation]
    words_wo_punct=''.join(no_punct)
    return words_wo_punct

# %%
def text_process(df):
    df['body']=df['body'].apply(lambda x: remove_punctuation(x.lower())) # Removing all the punctuations from the words, and changing the words to lower case to maintain uniformity
    stemmer = PorterStemmer() # stemming
    words = stopwords.words("english") # stop words example: "the, I, our etc"
    df['cleaned_reviews']= df['body'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]).lower())
    return df

# %%
text_process(df)
# Out:
# C:\Users\vinis\AppData\Local\Temp/ipykernel_5188/393806633.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['body']=df['body'].apply(lambda x: remove_punctuation(x.lower())) # Removing all the punctuations from the words, and changing the words to lower case to maintain uniformity
# C:\Users\vinis\AppData\Local\Temp/ipykernel_5188/393806633.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned_reviews']= df['body'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]).lower())
#                                              title  rating  \
# 0                                 Horrible product     1.0
# 1                                          Overall     4.0
# 2          Camera quality is not like 48 megapixel     3.0
# 3                                 A big no from me     1.0
# 4                    Put your money somewhere else     1.0
# ...                                            ...     ...
# 4995                     It could have been better     2.0
# 4996  Superb battery life.......👌👌👌👌one ui best👌👌👌     4.0
# 4997                        Do not buy this phone,     3.0
# 4998        Kuch khas nhi phon mai cemara to 0 haj     5.0
# 4999                     Samsung's new budget king     5.0
#
#                                                    body  y  \
# 0     very disappointed with the overall performance...  0
# 1     got the mobile on the launch datebattery must ...  2
# 2                                 camera quality is low  1
# 3     1 it doesnt work with 50ghz wifi frequency 24g...  0
# 4     not worth buyingfaulty software poor display q...  0
# ...                                                 ... ..
# 4995  too heavy n bulgy in this era not good as seco...  0
# 4996  nice mobile  battery life is very good and cha...  2
# 4997  camera quality is not good look like 13mega pi...  1
# 4998  phon mai bettry  fingerprint shi hai bas bki k...  2
# 4999  this is a budget friendly phone from samsung  ...  2
#
#                                         cleaned_reviews
# 0                     disappoint overal perform samsung
# 1     got mobil launch datebatteri must appreciatedc...
# 2                                    camera qualiti low
# 3     doesnt work ghz wifi frequenc ghz old school c...
# 4     worth buyingfaulti softwar poor display qualit...
# ...                                                 ...
# 4995  heavi n bulgi era good second phone tooi suppo...
# 4996  nice mobil batteri life good charg also faston...
# 4997  camera qualiti good look like mega pixel camer...
# 4998  phon mai bettri fingerprint shi hai ba bki kuc...
# 4999  budget friendli phone samsung realli worth pri...
#
# [4991 rows x 5 columns]

# %%
df1=df[['rating','cleaned_reviews']]

# %%
df1
# Out:
#       rating                                    cleaned_reviews
# 0        1.0                  disappoint overal perform samsung
# 1        4.0  got mobil launch datebatteri must appreciatedc...
# 2        3.0                                 camera qualiti low
# 3        1.0  doesnt work ghz wifi frequenc ghz old school c...
# 4        1.0  worth buyingfaulti softwar poor display qualit...
# ...      ...                                                ...
# 4995     2.0  heavi n bulgi era good second phone tooi suppo...
# 4996     4.0  nice mobil batteri life good charg also faston...
# 4997     3.0  camera qualiti good look like mega pixel camer...
# 4998     5.0  phon mai bettri fingerprint shi hai ba bki kuc...
# 4999     5.0  budget friendli phone samsung realli worth pri...
#
# [4991 rows x 2 columns]

# %%
def ratings_to_categorical(x):
    if x == 5.0 or x==4.0:
        return "Positive"
    if x==3.0:
        return "Neutral" 
    return "Negative"

# %%
df1['category']=df1['rating'].apply(ratings_to_categorical)
df1
# Out:
# C:\Users\vinis\AppData\Local\Temp/ipykernel_5188/3556611186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['category']=df1['rating'].apply(ratings_to_categorical)
#       rating                                    cleaned_reviews  category
# 0        1.0                  disappoint overal perform samsung  Negative
# 1        4.0  got mobil launch datebatteri must appreciatedc...  Positive
# 2        3.0                                 camera qualiti low   Neutral
# 3        1.0  doesnt work ghz wifi frequenc ghz old school c...  Negative
# 4        1.0  worth buyingfaulti softwar poor display qualit...  Negative
# ...      ...                                                ...       ...
# 4995     2.0  heavi n bulgi era good second phone tooi suppo...  Negative
# 4996     4.0  nice mobil batteri life good charg also faston...  Positive
# 4997     3.0  camera qualiti good look like mega pixel camer...   Neutral
# 4998     5.0  phon mai bettri fingerprint shi hai ba bki kuc...  Positive
# 4999     5.0  budget friendli phone samsung realli worth pri...  Positive
#
# [4991 rows x 3 columns]

# %%
df1['category'].value_counts()
# Out:
# Positive    2864
# Negative    1518
# Neutral      609
# Name: category, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import en_core_web_sm  
import spacy
import re
nlp = spacy.load("en_core_web_md")

# %%
def normalize(msg):
    msg = re.sub('[^A-Za-z]+', ' ', msg) #remove special character and intergers
    doc = nlp(msg)
    res=[]
    for token in doc:
        if(token.is_stop or token.is_punct or token.is_currency or token.is_space or len(token.text) <= 2): #word filteration
            pass
        else:
            res.append(token.lemma_.lower())
    return res

df1["cleaned_reviews_1"] = df1["cleaned_reviews"].apply(normalize)
df1.head()
# Out:
#    rating                                    cleaned_reviews  category  \
# 0     1.0                  disappoint overal perform samsung  Negative
# 1     4.0  got mobil launch datebatteri must appreciatedc...  Positive
# 2     3.0                                 camera qualiti low   Neutral
# 3     1.0  doesnt work ghz wifi frequenc ghz old school c...  Negative
# 4     1.0  worth buyingfaulti softwar poor display qualit...  Negative
#
#                                    cleaned_reviews_1
# 0             [disappoint, overal, perform, samsung]
# 1  [get, mobil, launch, datebatteri, appreciatedc...
# 2                             [camera, qualiti, low]
# 3  [work, ghz, wifi, frequenc, ghz, old, school, ...
# 4  [worth, buyingfaulti, softwar, poor, display, ...

# %%
# words count
from collections import Counter
words_collection = Counter([words for subtext in df1['cleaned_reviews_1'] for words in subtext])
most_common = pd.DataFrame(words_collection.most_common(50))
most_common.columns = ['most_common_word','count']
most_common
# Out:
#    most_common_word  count
# 0              good   3106
# 1             phone   2966
# 2            camera   2047
# 3           batteri   1560
# 4           qualiti   1454
# 5             mobil   1136
# 6           samsung   1051
# 7               use    840
# 8           product    806
# 9               buy    765
# 10            price    764
# 11             life    655
# 12             like    606
# 13              bad    589
# 14             work    546
# 15              day    529
# 16          display    485
# 17             well    421
# 18             time    401
# 19           screen    397
# 20             nice    393
# 21            charg    365
# 22          perform    364
# 23            heavi    356
# 24           amazon    355
# 25           featur    330
# 26           budget    327
# 27      fingerprint    327
# 28            money    314
# 29           overal    293
# 30            great    293
# 31             poor    292
# 32             issu    281
# 33             look    279
# 34             slow    274
# 35           expect    266
# 36             fast    261
# 37              app    252
# 38          purchas    247
# 39             hang    242
# 40              low    240
# 41           averag    238
# 42             rang    236
# 43           backup    225
# 44             game    221
# 45           realli    217
# 46           awesom    212
# 47          problem    212
# 48           sensor    201
# 49            month    200

# %%
#Visualizing results (Barchart for top 30 words)
most_common[0:30].plot.bar(x='most_common_word',figsize=(12,8),title='Top 30 words')
# Out:
# <AxesSubplot:title={'center':'Top 30 words'}, xlabel='most_common_word'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
fig, axes = plt.subplots(1, figsize=(15,8))
fig.suptitle("Comparing Ratio of Neutral Negative and Positive ratings", fontsize = 25)
plt.tight_layout(pad = 3.5)
sns.countplot(x = "category", data = df1)
axes.set_xlabel("Sentiment", fontsize = 20)
axes.set_ylabel("Count", fontsize = 20)
sns.despine()

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)
def word_cloud(data, title):
    wordcloud = WordCloud(
    background_color = "black",
    max_font_size = 40,
    max_words = 200,
    stopwords = stopwords,
    scale = 3).generate(str(data))
    fig = plt.figure(figsize = (7.5, 7.5))
    plt.axis("off")
    if title: 
        fig.suptitle(title, fontsize=15)
        fig.subplots_adjust(top=2.25)
    plt.imshow(wordcloud)
    plt.show()

# %%
neu=df1[df1["category"] == "Neutral"]["cleaned_reviews"]
neg=df1[df1["category"] == "Negative"]["cleaned_reviews"]
pos=df1[df1["category"] == "Positive"]["cleaned_reviews"]

# %%
word_cloud(neu, "Most Repeated words in neutral reviews")
word_cloud(pos, "Most Repeated words in positive reviews")
word_cloud(neg, "Most Repeated words in negative reviews")

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
from textblob import TextBlob

# %%
df1['polarity'] = df1['cleaned_reviews'].apply(lambda x: TextBlob(x).sentiment.polarity)
df1.head()
# Out:
#    rating                                    cleaned_reviews  category  \
# 0     1.0                  disappoint overal perform samsung  Negative
# 1     4.0  got mobil launch datebatteri must appreciatedc...  Positive
# 2     3.0                                 camera qualiti low   Neutral
# 3     1.0  doesnt work ghz wifi frequenc ghz old school c...  Negative
# 4     1.0  worth buyingfaulti softwar poor display qualit...  Negative
#
#                                    cleaned_reviews_1  polarity
# 0             [disappoint, overal, perform, samsung]  0.000000
# 1  [get, mobil, launch, datebatteri, appreciatedc...  0.137500
# 2                             [camera, qualiti, low]  0.000000
# 3  [work, ghz, wifi, frequenc, ghz, old, school, ...  0.078788
# 4  [worth, buyingfaulti, softwar, poor, display, ... -0.050000

# %%
top2_words = get_top_n2_words(df1["cleaned_reviews"], n=200) #top 200
top2_df = pd.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
top2_df.head(50)
# Out:
#                Bi-gram  Freq
# 0       camera qualiti   667
# 1         batteri life   545
# 2           good phone   210
# 3         good batteri   191
# 4       batteri backup   185
# 5           price rang   183
# 6         qualiti good   183
# 7          good camera   172
# 8           phone good   152
# 9         finger print   140
# 10         camera good   136
# 11            dont buy   136
# 12           life good   129
# 13          valu money   126
# 14           also good   118
# 15        front camera   114
# 16        budget phone   111
# 17         phone price   102
# 18         media could   101
# 19          could load   101
# 20           use phone   101
# 21        good product   101
# 22              gb ram    98
# 23  fingerprint reader    96
# 24        qualiti poor    83
# 25       samsung phone    81
# 26          good mobil    80
# 27         mah batteri    79
# 28  fingerprint sensor    77
# 29           buy phone    73
# 30        refresh rate    72
# 31          wast money    68
# 32        batteri good    66
# 33          best phone    66
# 34          nice phone    66
# 35       work properli    65
# 36        phone camera    65
# 37         mobil phone    65
# 38         overal good    64
# 39      samsung galaxi    59
# 40           mp camera    59
# 41        qualiti also    59
# 42       sound qualiti    58
# 43      camera batteri    57
# 44        good qualiti    57
# 45           littl bit    56
# 46     display qualiti    55
# 47       phone samsung    53
# 48          good price    52
# 49       samsung mobil    51

# %%
top20_bigram = top2_df.iloc[0:20,:]
fig = plt.figure(figsize = (10, 5))
plot=sns.barplot(x=top20_bigram["Bi-gram"],y=top20_bigram["Freq"],color = 'maroon')
plot.set_xticklabels(rotation=45,labels = top20_bigram["Bi-gram"])
# Out:
# [Text(0, 0, 'camera qualiti'),
#  Text(1, 0, 'batteri life'),
#  Text(2, 0, 'good phone'),
#  Text(3, 0, 'good batteri'),
#  Text(4, 0, 'batteri backup'),
#  Text(5, 0, 'price rang'),
#  Text(6, 0, 'qualiti good'),
#  Text(7, 0, 'good camera'),
#  Text(8, 0, 'phone good'),
#  Text(9, 0, 'finger print'),
#  Text(10, 0, 'camera good'),
#  Text(11, 0, 'dont buy'),
#  Text(12, 0, 'life good'),
#  Text(13, 0, 'valu money'),
#  Text(14, 0, 'also good'),
#  Text(15, 0, 'front camera'),
#  Text(16, 0, 'budget phone'),
#  Text(17, 0, 'phone price'),
#  Text(18, 0, 'media could'),
#  Text(19, 0, 'could load')]

# %%
def get_top_n3_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(3,3), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top3_words = get_top_n3_words(df["cleaned_reviews"], n=200)
top3_df = pd.DataFrame(top3_words)
top3_df.columns=["Tri-gram", "Freq"]
top3_df.head(20)
# Out:
#                 Tri-gram  Freq
# 0      batteri life good   114
# 1    camera qualiti good   105
# 2       media could load   101
# 3      good batteri life    79
# 4    good camera qualiti    62
# 5    camera qualiti poor    54
# 6    finger print reader    45
# 7       phone price rang    39
# 8    good batteri backup    38
# 9    batteri backup good    37
# 10       hz refresh rate    36
# 11   batteri life camera    36
# 12   finger print sensor    34
# 13      good phone price    30
# 14   camera qualiti also    30
# 15             gb ram gb    29
# 16    camera qualiti bad    27
# 17     qualiti also good    27
# 18  phone camera qualiti    26
# 19      life good camera    26

# %%
import seaborn as sns
top20_trigram = top3_df.iloc[0:20,:]
fig = plt.figure(figsize = (10, 5))
plot=sns.barplot(x=top20_trigram["Tri-gram"],y=top20_trigram["Freq"], color = 'maroon')
plot.set_xticklabels(rotation=45,labels = top20_trigram["Tri-gram"])
# Out:
# [Text(0, 0, 'batteri life good'),
#  Text(1, 0, 'camera qualiti good'),
#  Text(2, 0, 'media could load'),
#  Text(3, 0, 'good batteri life'),
#  Text(4, 0, 'good camera qualiti'),
#  Text(5, 0, 'camera qualiti poor'),
#  Text(6, 0, 'finger print reader'),
#  Text(7, 0, 'phone price rang'),
#  Text(8, 0, 'good batteri backup'),
#  Text(9, 0, 'batteri backup good'),
#  Text(10, 0, 'hz refresh rate'),
#  Text(11, 0, 'batteri life camera'),
#  Text(12, 0, 'finger print sensor'),
#  Text(13, 0, 'good phone price'),
#  Text(14, 0, 'camera qualiti also'),
#  Text(15, 0, 'gb ram gb'),
#  Text(16, 0, 'camera qualiti bad'),
#  Text(17, 0, 'qualiti also good'),
#  Text(18, 0, 'phone camera qualiti'),
#  Text(19, 0, 'life good camera')]

# %%
sns.catplot(y = 'rating' , kind = 'count',data = df, color =  'red')

# %%
df1['polarity'] = df1['cleaned_reviews'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
num_bins = 50
plt.figure(figsize=(10,6))
plt.hist(df1.polarity, num_bins, alpha=0.5, color = 'blue', ec = 'red')
plt.xlabel('Polarity')
plt.ylabel('Count')
plt.title('Histogram of polarity')
# Out:
# Text(0.5, 1.0, 'Histogram of polarity')

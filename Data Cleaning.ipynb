# %%
import pandas as pd
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

import nltk
import re
import string
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vinis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
df=pd.read_csv("realme.csv")
df
# Out:
#                                     date  \
# 0      Reviewed in India on 1 April 2021
# 1     Reviewed in India on 24 March 2021
# 2     Reviewed in India on 26 April 2021
# 3     Reviewed in India on 29 April 2021
# 4     Reviewed in India on 17 April 2021
# ...                                  ...
# 9435  Reviewed in India on 19 April 2021
# 9436    Reviewed in India on 9 June 2021
# 9437   Reviewed in India on 2 April 2021
# 9438    Reviewed in India on 1 June 2021
# 9439     Reviewed in India on 2 May 2021
#
#                                      title  rating  \
# 0     Good one but not worth the price tag     3.0
# 1                               REDUCULOUS     1.0
# 2            Thi product is very helpfuly.     4.0
# 3      Wrist band cause severe skin rashes     1.0
# 4      Waste of money and no return policy     1.0
# ...                                    ...     ...
# 9435      Great watch but not for fitness.     2.0
# 9436         Stay away from realme watch s     1.0
# 9437                        Return pleases     5.0
# 9438                    Buy for looks only     3.0
# 9439              Display Whitish  Problem     1.0
#
#                                                    body
# 0     What I like most -1. Heart Beat Tracking - Exc...
# 1     not proper working and touch pad is reduculas....
# 2     This product is best.battery life 7-8days, hea...
# 3     The watch is okay okay but the wrist band is p...
# 4     Don't waste you money in buying this. It's ver...
# ...                                                 ...
# 9435  I bought this watch with extremely high expect...
# 9436  It's just a fitness tracker with bigger dial w...
# 9437  Products was good per not useful sorry I am re...
# 9438  I posted same comment on realme community post...
# 9439  Dear Realme & Amazon,I bought  Realms watch on...
#
# [9440 rows x 4 columns]

# %%
def classify(x):
    if x == 5.0 or x==4.0:
        return 2
    if x==3.0:
        return 1 
    return 0

# %%
def clean_dataframe(df):
  # creates new column with corresponding class labels, the output variable.
  df['y'] = df['rating'].apply(classify)

# %%
clean_dataframe(df)

# %%
df
# Out:
#                                     date  \
# 0      Reviewed in India on 1 April 2021
# 1     Reviewed in India on 24 March 2021
# 2     Reviewed in India on 26 April 2021
# 3     Reviewed in India on 29 April 2021
# 4     Reviewed in India on 17 April 2021
# ...                                  ...
# 9435  Reviewed in India on 19 April 2021
# 9436    Reviewed in India on 9 June 2021
# 9437   Reviewed in India on 2 April 2021
# 9438    Reviewed in India on 1 June 2021
# 9439     Reviewed in India on 2 May 2021
#
#                                      title  rating  \
# 0     Good one but not worth the price tag     3.0
# 1                               REDUCULOUS     1.0
# 2            Thi product is very helpfuly.     4.0
# 3      Wrist band cause severe skin rashes     1.0
# 4      Waste of money and no return policy     1.0
# ...                                    ...     ...
# 9435      Great watch but not for fitness.     2.0
# 9436         Stay away from realme watch s     1.0
# 9437                        Return pleases     5.0
# 9438                    Buy for looks only     3.0
# 9439              Display Whitish  Problem     1.0
#
#                                                    body  y
# 0     What I like most -1. Heart Beat Tracking - Exc...  1
# 1     not proper working and touch pad is reduculas....  0
# 2     This product is best.battery life 7-8days, hea...  2
# 3     The watch is okay okay but the wrist band is p...  0
# 4     Don't waste you money in buying this. It's ver...  0
# ...                                                 ... ..
# 9435  I bought this watch with extremely high expect...  0
# 9436  It's just a fitness tracker with bigger dial w...  0
# 9437  Products was good per not useful sorry I am re...  2
# 9438  I posted same comment on realme community post...  1
# 9439  Dear Realme & Amazon,I bought  Realms watch on...  0
#
# [9440 rows x 5 columns]

# %%
df['body']
# Out:
# 0       What I like most -1. Heart Beat Tracking - Exc...
# 1       not proper working and touch pad is reduculas....
# 2       This product is best.battery life 7-8days, hea...
# 3       The watch is okay okay but the wrist band is p...
# 4       Don't waste you money in buying this. It's ver...
#                               ...
# 9435    I bought this watch with extremely high expect...
# 9436    It's just a fitness tracker with bigger dial w...
# 9437    Products was good per not useful sorry I am re...
# 9438    I posted same comment on realme community post...
# 9439    Dear Realme & Amazon,I bought  Realms watch on...
# Name: body, Length: 9440, dtype: object

# %%
# removes all the punctuations ie '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
import string
def remove_punctuation(text):
    no_punct=[words for words in text if words not in string.punctuation]
    words_wo_punct=''.join(no_punct)
    return words_wo_punct

# %%
def text_process(df):
    df['body']=df['body'].apply(lambda x: remove_punctuation(x.lower())) # Removing all the punctuations from the words, and changing the words to lower case to maintain uniformity
    stemmer = PorterStemmer() # stemming
    words = stopwords.words("english") # stop words example: "the, I, our etc"
    df['cleaned_reviews']= df['body'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]).lower())
    return df

# %%
text_process(df)
# Out:
#                                     date  \
# 0      Reviewed in India on 1 April 2021
# 1     Reviewed in India on 24 March 2021
# 2     Reviewed in India on 26 April 2021
# 3     Reviewed in India on 29 April 2021
# 4     Reviewed in India on 17 April 2021
# ...                                  ...
# 9435  Reviewed in India on 19 April 2021
# 9436    Reviewed in India on 9 June 2021
# 9437   Reviewed in India on 2 April 2021
# 9438    Reviewed in India on 1 June 2021
# 9439     Reviewed in India on 2 May 2021
#
#                                      title  rating  \
# 0     Good one but not worth the price tag     3.0
# 1                               REDUCULOUS     1.0
# 2            Thi product is very helpfuly.     4.0
# 3      Wrist band cause severe skin rashes     1.0
# 4      Waste of money and no return policy     1.0
# ...                                    ...     ...
# 9435      Great watch but not for fitness.     2.0
# 9436         Stay away from realme watch s     1.0
# 9437                        Return pleases     5.0
# 9438                    Buy for looks only     3.0
# 9439              Display Whitish  Problem     1.0
#
#                                                    body  y  \
# 0     what i like most 1 heart beat tracking  excell...  1
# 1     not proper working and touch pad is reduculas ...  0
# 2     this product is bestbattery life 78days heart ...  2
# 3     the watch is okay okay but the wrist band is p...  0
# 4     dont waste you money in buying this its very m...  0
# ...                                                 ... ..
# 9435  i bought this watch with extremely high expect...  0
# 9436  its just a fitness tracker with bigger dial wh...  0
# 9437  products was good per not useful sorry i am re...  2
# 9438  i posted same comment on realme community post...  1
# 9439  dear realme  amazoni bought  realms watch on 1...  0
#
#                                         cleaned_reviews
# 0     like heart beat track excel spo excel batteri ...
# 1     proper work touch pad reducula bad perfom prou...
# 2     product bestbatteri life day heart rate sensor...
# 3     watch okay okay wrist band pathet got sever sk...
# 4     dont wast money buy much cheap qualiti product...
# ...                                                 ...
# 9435  bought watch extrem high expect consid hype ar...
# 9436  fit tracker bigger dial doesnt get job doneif ...
# 9437             product good per use sorri return item
# 9438  post comment realm commun postwatch look good ...
# 9439  dear realm amazoni bought realm watch apr im g...
#
# [9440 rows x 6 columns]

# %%
df['body'],df['cleaned_reviews']
# Out:
# (0       what i like most 1 heart beat tracking  excell...
#  1       not proper working and touch pad is reduculas ...
#  2       this product is bestbattery life 78days heart ...
#  3       the watch is okay okay but the wrist band is p...
#  4       dont waste you money in buying this its very m...
#                                ...
#  9435    i bought this watch with extremely high expect...
#  9436    its just a fitness tracker with bigger dial wh...
#  9437    products was good per not useful sorry i am re...
#  9438    i posted same comment on realme community post...
#  9439    dear realme  amazoni bought  realms watch on 1...
#  Name: body, Length: 9440, dtype: object,
#  0       like heart beat track excel spo excel batteri ...
#  1       proper work touch pad reducula bad perfom prou...
#  2       product bestbatteri life day heart rate sensor...
#  3       watch okay okay wrist band pathet got sever sk...
#  4       dont wast money buy much cheap qualiti product...
#                                ...
#  9435    bought watch extrem high expect consid hype ar...
#  9436    fit tracker bigger dial doesnt get job doneif ...
#  9437               product good per use sorri return item
#  9438    post comment realm commun postwatch look good ...
#  9439    dear realm amazoni bought realm watch apr im g...
#  Name: cleaned_reviews, Length: 9440, dtype: object)

# %%
df2 = pd.DataFrame(df)
df2.to_csv(r'updated_dataset.csv', index=False)

# %%
df2
# Out:
#                                     date  \
# 0      Reviewed in India on 1 April 2021
# 1     Reviewed in India on 24 March 2021
# 2     Reviewed in India on 26 April 2021
# 3     Reviewed in India on 29 April 2021
# 4     Reviewed in India on 17 April 2021
# ...                                  ...
# 9435  Reviewed in India on 19 April 2021
# 9436    Reviewed in India on 9 June 2021
# 9437   Reviewed in India on 2 April 2021
# 9438    Reviewed in India on 1 June 2021
# 9439     Reviewed in India on 2 May 2021
#
#                                      title  rating  \
# 0     Good one but not worth the price tag     3.0
# 1                               REDUCULOUS     1.0
# 2            Thi product is very helpfuly.     4.0
# 3      Wrist band cause severe skin rashes     1.0
# 4      Waste of money and no return policy     1.0
# ...                                    ...     ...
# 9435      Great watch but not for fitness.     2.0
# 9436         Stay away from realme watch s     1.0
# 9437                        Return pleases     5.0
# 9438                    Buy for looks only     3.0
# 9439              Display Whitish  Problem     1.0
#
#                                                    body  y  \
# 0     what i like most 1 heart beat tracking  excell...  1
# 1     not proper working and touch pad is reduculas ...  0
# 2     this product is bestbattery life 78days heart ...  2
# 3     the watch is okay okay but the wrist band is p...  0
# 4     dont waste you money in buying this its very m...  0
# ...                                                 ... ..
# 9435  i bought this watch with extremely high expect...  0
# 9436  its just a fitness tracker with bigger dial wh...  0
# 9437  products was good per not useful sorry i am re...  2
# 9438  i posted same comment on realme community post...  1
# 9439  dear realme  amazoni bought  realms watch on 1...  0
#
#                                         cleaned_reviews
# 0     like heart beat track excel spo excel batteri ...
# 1     proper work touch pad reducula bad perfom prou...
# 2     product bestbatteri life day heart rate sensor...
# 3     watch okay okay wrist band pathet got sever sk...
# 4     dont wast money buy much cheap qualiti product...
# ...                                                 ...
# 9435  bought watch extrem high expect consid hype ar...
# 9436  fit tracker bigger dial doesnt get job doneif ...
# 9437             product good per use sorri return item
# 9438  post comment realm commun postwatch look good ...
# 9439  dear realm amazoni bought realm watch apr im g...
#
# [9440 rows x 6 columns]
